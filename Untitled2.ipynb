# %%
import pandas as pd

# %%
import glob

# %%
from bin.consol.utils import load_dataset
# import bin

aime24df = load_dataset('aime24')

# %%
def get_model_problem_summary(globpath, n=40):
    assert n <= 40
    df = pd.concat([pd.read_csv(filepath, index_col=0).head(n).assign(id=int(filepath.split("/")[-1].split('.')[0])) for filepath in sorted(glob.glob(globpath))]).reset_index(drop=True)
    df2 = aime24df.target.to_frame()
    df2['answer'] = df.groupby('id').answer.agg(lambda x: x.value_counts().index[0])
    df2['trials'] = df.groupby('id').token_usage.count()
    df2['token_usage'] = df.groupby('id').token_usage.sum()
    return df2

def get_model_summary(df):
    return pd.Series({
        "mean_token_usage": df.token_usage.mean(),
        "estimated_price": df.token_usage.sum() * 4.40 / 1e6,
        "accuracy": (df.target == df.answer).mean(),
    })

# get_model_summary(get_model_problem_summary("resources/gpt4o-aime24-ac/*"))

# %%
pd.read_csv("./resources/o3minihigh-aime24-ac/0.csv", index_col=0)
# Out:
#    answer  token_usage
# 0    33.0          914
# 1    33.0         1750
# 2    33.0         1492
# 3    33.0         1555
# 4    33.0         1554

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid", palette="pastel")

# %%
ax = (100 - 100*pd.Series([
    get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-vote/*", n=40)).mean_token_usage,
    get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-vote/*", n=40)).mean_token_usage,
    get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-vote/*", n=40)).mean_token_usage,
])[::-1]).to_frame().assign(label=["o3-mini-low", "o3-mini-medium", "o3-mini-high"]).set_index('label').plot.bar(ylabel="Cost Efficeicny (%)", xlabel="", rot=0, legend=False)

plt.savefig("cost_efficiency.pdf", bbox_inches='tight', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 ax = (100 - 100*pd.Series([
# ----> 2     get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)).mean_token_usage,
#       3     get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=40)).mean_token_usage,
#       4     get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-pvalue/*", n=40)).mean_token_usage / get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=40)).mean_token_usage,
#       5 ])[::-1]).to_frame().assign(label=["o3-mini-low", "o3-mini-medium", "o3-mini-high"]).set_index('label').plot.bar(ylabel="Cost Efficeicny (%)", xlabel="", rot=0, legend=False)
#       7 plt.savefig("cost_efficiency.pdf", bbox_inches='tight', dpi=300)
#
# Cell In[5], line 3, in get_model_problem_summary(globpath, n)
#       1 def get_model_problem_summary(globpath, n=40):
#       2     assert n <= 40
# ----> 3     df = pd.concat([pd.read_csv(filepath, index_col=0).head(n).assign(id=int(filepath.split("/")[-1].split('.')[0])) for filepath in sorted(glob.glob(globpath))]).reset_index(drop=True)
#       4     df2 = aime24df.target.to_frame()
#       5     df2['answer'] = df.groupby('id').answer.agg(lambda x: x.value_counts().index[0])
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
(
    get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=1)),
    get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sprt/*", n=1)),

    get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)),
    get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sprt/*", n=40)),
)
# Out:
# (mean_token_usage    10705.900000
#  estimated_price         1.413179
#  accuracy                0.933333
#  dtype: float64,
#  mean_token_usage    8836.433333
#  estimated_price        1.166409
#  accuracy               0.966667
#  dtype: float64,
#  mean_token_usage    429933.666667
#  estimated_price         56.751244
#  accuracy                 0.966667
#  dtype: float64,
#  mean_token_usage    286785.100000
#  estimated_price         37.855633
#  accuracy                 0.966667
#  dtype: float64)

# %%
(
    get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=1)),
    get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sprt/*", n=1)),

    get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=40)),
    get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sprt/*", n=40)),
)
# Out:
# (mean_token_usage    5925.533333
#  estimated_price        0.782170
#  accuracy               0.733333
#  dtype: float64,
#  mean_token_usage    5226.133333
#  estimated_price        0.689850
#  accuracy               0.733333
#  dtype: float64,
#  mean_token_usage    199685.566667
#  estimated_price         26.358495
#  accuracy                 0.900000
#  dtype: float64,
#  mean_token_usage    146801.366667
#  estimated_price         19.377780
#  accuracy                 0.900000
#  dtype: float64)

# %%
(
    get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=1)),
    get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sprt/*", n=1)),

    get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=40)),
    get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sprt/*", n=40)),
)
# Out:
# (mean_token_usage    1387.033333
#  estimated_price        0.183088
#  accuracy               0.533333
#  dtype: float64,
#  mean_token_usage    1592.200000
#  estimated_price        0.210170
#  accuracy               0.566667
#  dtype: float64,
#  mean_token_usage    65501.733333
#  estimated_price         8.646229
#  accuracy                0.700000
#  dtype: float64,
#  mean_token_usage    53973.700000
#  estimated_price         7.124528
#  accuracy                0.700000
#  dtype: float64)

# %%
fig, axes = plt.subplots(2,1, figsize=(6, 10))
axes[0].set_ylim(0,1.2)

sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="accuracy",
    hue="hue",
    ax=axes[0],
)


sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="estimated_price",
    hue="hue",
    ax=axes[1],
)
# Out:
# <Axes: xlabel='max_trials', ylabel='estimated_price'>

# %%
fig, axes = plt.subplots(2,1, figsize=(6, 10))
axes[0].set_ylim(0,1.2)

sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="accuracy",
    hue="hue",
    ax=axes[0],
)


sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="estimated_price",
    hue="hue",
    ax=axes[1],
)
# Out:
# <Axes: xlabel='max_trials', ylabel='estimated_price'>

# %%
fig, axes = plt.subplots(2,1, figsize=(6, 10))
axes[0].set_ylim(0,1.2)

sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="accuracy",
    hue="hue",
    ax=axes[0],
)


sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minimedium-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="estimated_price",
    hue="hue",
    ax=axes[1],
)
# Out:
# <Axes: xlabel='max_trials', ylabel='estimated_price'>

# %%
fig, axes = plt.subplots(2,1, figsize=(6, 10))
axes[0].set_ylim(0,1.2)

# axes[0].set_title('o3-mini-low')

sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="accuracy",
    hue="hue",
    ax=axes[0],
)


sns.barplot(
    data=pd.concat([
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=1)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=1)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=5)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=5)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=10)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=10)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=20)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=20)),

        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-sc/*", n=40)),
        get_model_summary(get_model_problem_summary("resources/o3minilow-aime24-ac/*", n=40)),
    ], axis=1).T.assign(max_trials=[1,1,5,5,10,10,20,20,40,40], hue=["Self-Consistency", "Ours"]*5),
    x="max_trials",
    y="estimated_price",
    hue="hue",
    ax=axes[1],
)
# Out:
# <Axes: xlabel='max_trials', ylabel='estimated_price'>

# %%
fig, axes = plt.subplots(1, 3, figsize = (17, 4))
fig.suptitle("Stacked Histogram of Trials for Correct and Incorrect Answers")

df = get_model_problem_summary("resources/o3minilow-aime24-sprt/*", n=40)

# Extract trials for correct and incorrect answers
correct_trials = df[df.target == df.answer].trials
incorrect_trials = df[df.target != df.answer].trials

# Plot stacked histogram
axes[0].hist([correct_trials, incorrect_trials], stacked=True, label=["Correct", "Incorrect"], alpha=0.7)

axes[0].set_title("o3-mini-low")
axes[0].set_xlabel("Number of Trials")
axes[0].set_ylabel("Frequency")
axes[0].legend()

df = get_model_problem_summary("resources/o3minimedium-aime24-sprt/*", n=40)

# Extract trials for correct and incorrect answers
correct_trials = df[df.target == df.answer].trials
incorrect_trials = df[df.target != df.answer].trials

# Plot stacked histogram
axes[1].hist([correct_trials, incorrect_trials], stacked=True, label=["Correct", "Incorrect"], alpha=0.7)

axes[1].set_title("o3-mini-medium")
axes[1].set_xlabel("Number of Trials")
axes[1].set_ylabel("Frequency")
axes[1].legend()


df = get_model_problem_summary("resources/o3minihigh-aime24-sprt/*", n=40)

# Extract trials for correct and incorrect answers
correct_trials = df[df.target == df.answer].trials
incorrect_trials = df[df.target != df.answer].trials

# Plot stacked histogram
axes[2].hist([correct_trials, incorrect_trials], stacked=True, label=["Correct", "Incorrect"], alpha=0.7)

axes[2].set_title("o3-mini-high")
axes[2].set_xlabel("Number of Trials")
axes[2].set_ylabel("Frequency")
axes[2].legend()

plt.savefig("stacked_histogram.pdf", bbox_inches='tight', dpi=300)

# %%
df = get_model_problem_summary("resources/o3minihigh-aime24-ac/*", n=40)

print(df.to_csv())
# Out:
# ,target,answer,trials,token_usage
# 0,33,33.0,5,7265
# 1,23,23.0,5,32356
# 2,116,116.0,5,4250
# 3,809,809.0,5,13110
# 4,197,197.0,16,639111
# 5,385,24.0,40,1704381
# 6,371,371.0,39,1068382
# 7,601,601.0,5,32049
# 8,25,25.0,5,7086
# 9,55,55.0,5,9581
# 10,540,540.0,5,7538
# 11,45,45.0,5,15736
# 12,204,204.0,5,8114
# 13,699,699.0,5,119840
# 14,294,294.0,5,8631
# 15,110,110.0,5,43767
# 16,721,721.0,5,8160
# 17,315,315.0,31,1198416
# 18,468,468.0,5,68403
# 19,902,902.0,5,45238
# 20,211,211.0,5,73717
# 21,80,80.0,5,195551
# 22,480,480.0,5,34744
# 23,236,236.0,5,49052
# 24,73,73.0,5,8856
# 25,113,113.0,5,54822
# 26,127,127.0,5,120287
# 27,104,104.0,38,294567
# 28,104,104.0,8,45602
# 29,321,321.0,5,13995
